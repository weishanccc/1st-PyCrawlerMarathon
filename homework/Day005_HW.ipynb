# %% [markdown]
# # API 資料串接 - 以 Dcard API 實作範例
#
# * 了解 Dcard API 使用方式與回傳內容
# * 撰寫程式存取 API 且解析 JSON 格式資料

# %% [markdown]
# ## 作業目標
#
# * 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
#
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

# %%
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？

'''
Your Code
'''

import requests
import json

#Retrieve Data
r = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=true')
response = r.text

data = json.loads(response)
print('一次回傳', len(data), '筆資料')
print('資料包含的欄位有：', data[0].keys())
# Out:
# 一次回傳 30 筆資料
# 資料包含的欄位有： dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'gender', 'school', 'department', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])

# %%
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」

'''
Your Code
'''
import pandas as p
listout = []
for article in data:
    listout.append([article['title'], article['createdAt'], article['commentCount'], article['likeCount']])

listout_p = p.DataFrame(listout, columns = ['標題', '貼文時間', '留言人數', '按讚人數'])
listout_p


listout_p.style.set_properties(**{'text-align': 'left'})
# Out:
# <style  type="text/css" >
#     #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow0_col0 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow0_col1 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow0_col2 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow0_col3 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow1_col0 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow1_col1 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow1_col2 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow1_col3 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow2_col0 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow2_col1 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow2_col2 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow2_col3 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow3_col0 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow3_col1 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow3_col2 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow3_col3 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow4_col0 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow4_col1 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow4_col2 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow4_col3 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow5_col0 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow5_col1 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow5_col2 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow5_col3 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow6_col0 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow6_col1 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow6_col2 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow6_col3 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow7_col0 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow7_col1 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow7_col2 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow7_col3 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow8_col0 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow8_col1 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow8_col2 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow8_col3 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow9_col0 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow9_col1 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow9_col2 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow9_col3 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow10_col0 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow10_col1 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow10_col2 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow10_col3 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow11_col0 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow11_col1 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow11_col2 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow11_col3 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow12_col0 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow12_col1 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow12_col2 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow12_col3 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow13_col0 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow13_col1 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow13_col2 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow13_col3 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow14_col0 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow14_col1 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow14_col2 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow14_col3 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow15_col0 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow15_col1 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow15_col2 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow15_col3 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow16_col0 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow16_col1 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow16_col2 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow16_col3 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow17_col0 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow17_col1 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow17_col2 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow17_col3 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow18_col0 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow18_col1 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow18_col2 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow18_col3 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow19_col0 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow19_col1 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow19_col2 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow19_col3 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow20_col0 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow20_col1 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow20_col2 {
#             text-align:  left;
#         }    #T_33cb200a_1b5d_11ea_a02f_9cb6d00c5e0arow

# %%
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

'''
Your Code
'''
def questionthree(is_popular):
    r = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=' + is_popular)
    response = r.text
    alldata = json.loads(response)
    listout = []    
    for article in alldata:
        listout.append([article['title'], article['createdAt'], article['commentCount'], article['likeCount']])
    hd = p.DataFrame(listout, columns = ['標題', '日期', '留言人數', '按讚人數'])
    if is_popular == 'true':
        hot_type = '熱門'        
    else:
        hot_type = '非熱門'        
    print(hot_type + '文章平均留言人數: ' + str(round(hd['留言人數'].mean(),1)))
    print(hot_type + '文章平均按讚人數: ' + str(round(hd['按讚人數'].mean(),1)))

# %%
questionthree('true')
# Out:
# 熱門文章平均留言人數: 6.7
# 熱門文章平均按讚人數: 122.8

# %%
questionthree('false')
# Out:
# 非熱門文章平均留言人數: 2.6
# 非熱門文章平均按讚人數: 7.0
